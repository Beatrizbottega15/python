# %% [markdown]
# <a href="https://colab.research.google.com/github/Beatrizbottega15/python/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**aula 1** 🏐 🍍 🌸

# %%
ano = "IV"
print(ano, "competição de programação dá Start")
# Out:
# IV competição de programação dá Start

# %% [markdown]
# #**aula 2** ⛅ 🍊 🧘

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6
pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil
pontos_ana = 2 * livro_ficcao + 5* livro_infantil
pontos_totais = pontos_rodrigo + pontos_ana
print(f"Os pontos totais do Rodrigo são {pontos_rodrigo}")
print(f"Os pontos totais do Ana são {pontos_ana}")
print(f"Os pontos totais de Ana e Rodrigo são {pontos_totais}")
# Out:
# Os pontos totais do Rodrigo são 24
# Os pontos totais do Ana são 46
# Os pontos totais de Ana e Rodrigo são 70

# %% [markdown]
# #**aula 3**  ⛪ ⏳ ✨

# %%
total_de_figurinhas = int(input("Digite o total de figurinhas: "))
numero_de_amigos = int(input("Digite o número de amigos: "))
figurinhas_amigo = total_de_figurinhas // (numero_de_amigos + 2)
figurinhas_joao = 2 * figurinhas_amigo
figurinhas_extras = int(input("Digite o número de figurinhas extras: "))
figurinhas_extras = figurinhas_extras // (numero_de_amigos + 2)
figurinhas

print(f"João recebeu {figurinhas_joao} figurinhas")
# Out:
# Digite o total de figurinhas: 30
# Digite o número de amigos: 4
# João recebeu 10 figurinhas

# %% [markdown]
# #**aula 4** ♌ ❤ ⚡
#
# ##dia de prova

# %%
P = int(input("Digite a posição da porta P (0 ou 1): "))
R = int(input("Digite a posição da porta R (0 ou 1): "))
if P == 0:
    print("C")
elif R == 1:
    print("A")
else:
    print("B")
# Out:
# Digite a posição da porta P (0 ou 1): 1
# Digite a posição da porta R (0 ou 1): 1
# A

# %% [markdown]
# #**aula 5 - cálculo de IMC** 🥇 💙 🩸

# %%
peso = float(input("Digite seu peso (em kg): "))
altura = float(input("Digite sua altura (em metros): "))
imc = peso / (altura ** 2)
print(f"\nSeu IMC é: {imc:.2f}")
if imc < 18.5:
    print("Você está abaixo do peso.")
elif 18.5 <= imc < 25:
    print("Você está no peso ideal.")
elif 25 <= imc < 30:
    print("Você está com sobrepeso.")
else:
    print("Você está acima do peso.")
# Out:
# Digite seu peso (em kg): 54
# Digite sua altura (em metros): 1.80
#
# Seu IMC é: 16.67
# Você está abaixo do peso.

# %% [markdown]
# #***aula 6 tabuada*** 🐜 💓 👅

# %%
def tabuada(numero):
    for contador in range(1, 11):  # Gera números de 1 a 10
        print(f"{numero} x {contador} = {numero * contador}")
numero = int(input("Digite um número para ver sua tabuada: "))
tabuada(numero)
# Out:
# Digite um número para ver sua tabuada: 23
# 23 x 1 = 23
# 23 x 2 = 46
# 23 x 3 = 69
# 23 x 4 = 92
# 23 x 5 = 115
# 23 x 6 = 138
# 23 x 7 = 161
# 23 x 8 = 184
# 23 x 9 = 207
# 23 x 10 = 230

# %% [markdown]
# #**aula 7 idade** 🐮 💵 💖

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
  idade_filho3 = idade_monica - idade_filho1 - idade_filho2
  idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)
  return idade_filho3, idade_maxima
resultado = calcula_idade_maior(68, 12, 30)
print(resultado)
# Out:
# (26, 30)

# %% [markdown]
# #**aula 8** ◀ ✅ ☔

# %%
print("sou seu assistente virtual \n")
nome = input("digite seu nome: ")
print(f"olá {nome}, em que posso ajudar?")
resposta = input("Qual assunto você deseja tratar? matemática, python ou javascript: ").lower()
if resposta=="python":
  print("Ótimo, vamos falar sobre Python!")
  print("Python é uma linguagem de programação de alto nível, conhecida pela sua simplicidade e legibilidade. Criada por Guido van Rossum em 1991, ela é usada em diversas áreas como desenvolvimento web, ciência de dados, automação e inteligência artificial. Sua sintaxe clara facilita o aprendizado, tornando-a ideal tanto para iniciantes quanto para programadores experientes. Embora não seja a mais rápida em termos de desempenho, sua versatilidade e a grande comunidade de desenvolvedores compensam essa limitação, tornando Python uma das linguagens mais populares e amplamente utilizadas no mundo.")
elif resposta=="matemática":
  print("Perfeito, vamos resolver umas questões de matemática!")
  print("A matemática é a ciência que estuda números, formas e padrões. Ela nos ajuda a entender o mundo ao nosso redor e é fundamental em várias áreas, como ciência, tecnologia e economia. Através de ramos como álgebra, geometria e estatística, a matemática nos permite resolver problemas, fazer previsões e descobrir novas soluções. Ela é uma linguagem universal, usada para descrever e explicar tudo, desde fenômenos naturais até situações cotidianas.")
elif resposta=="javascript":
  print("Que legal, vamos conversar sobre javascript!")
else:
  print("Hum, não sei falar sobre esse assunto ")
# Out:
# sou seu assistente virtual
#
# digite seu nome: bia
# olá bia, em que posso ajudar?
# Qual assunto você deseja tratar? matemática, python ou javascript: javascript
# Que legal, vamos conversar sobre javascript!

# %% [markdown]
# #**Aula 9 listas** ⏲ ⏳ 🧘

# %%
import random
dica = [
"O sucesso é a soma de pequenos esforços repetidos dia após dia.🌟",
"A única maneira de fazer um excelente trabalho é amar o que você faz.💡",
"Acredite em si mesmo e todo o resto virá.💪",
"Desistir é para os fracos, persistir é para os fortes.🔥",
"O único limite para os nossos sonhos é a nossa própria mente.🚀",
"Grandes realizações nunca vêm de zonas de conforto.🌱",
"Não importa o quão devagar você vá, desde que não pare.🐢",
"O fracasso não é o oposto do sucesso, ele é parte do sucesso.💥",
"Tudo o que você precisa já está dentro de você.✨",
"A persistência é o caminho do êxito.🎯",
]
while True:
    pedido = input("Digite 'dica' para receber uma dica ou 'sair' para encerrar: ").lower()

    if pedido == "dica":
        dica_escolhida = random.choice(dica)  # escolhe uma dica aleatória
        print(f"Dica: {dica_escolhida}")

    elif pedido == "sair":
        print("Até mais!")
        break

    else:
        print("Comando não reconhecido. Tente novamente.")
